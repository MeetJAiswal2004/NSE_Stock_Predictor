# %%
from google.colab import drive
import os

print("🚀 Mounting Google Drive...")
drive.mount('/content/drive')

PROJECT_SERVER1_PATH = "/content/drive/My Drive/Stock_Predictor_NSE/server1"

os.chdir(PROJECT_SERVER1_PATH)
print(f"✅ Working directory set to: {os.getcwd()}")

print("🚀 Installing authentication dependencies...")
# !pip install -r requirements.txt --quiet
print("✅ All libraries installed successfully.")

print("\n🚀 Starting the Authentication server (server1) in the background...")
# !python auth_app.py &
# Out:
# 🚀 Mounting Google Drive...
# Mounted at /content/drive
# ✅ Working directory set to: /content/drive/My Drive/Stock_Predictor_NSE/server1
# 🚀 Installing authentication dependencies...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 55.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 20.5 MB/s eta 0:00:00
# ✅ All libraries installed successfully.
#
# 🚀 Starting the Authentication server (server1) in the background...
# ✅ SERVER 1 (Auth): MongoDB connected successfully.
# ...
# ✅ SERVER 1 (Auth) is live!
# 🔗 Auth URL: NgrokTunnel: "https://unaspersed-unwithstanding-journey.ngrok-free.app" -> "http://localhost:5000"
# ...
#  * Serving Flask app 'auth_app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
# ...

# %%
from google.colab import drive
import os

print("🚀 Mounting Google Drive for Server 2...")
drive.mount('/content/drive')

# --- AAPKA SAHI PATH YAHAN DAALEIN ---
PROJECT_SERVER2_PATH = "/content/drive/My Drive/Stock_Predictor_NSE/server2/backend"
# ------------------------------------

os.chdir(PROJECT_SERVER2_PATH)
print(f"✅ Working directory set to: {os.getcwd()}")
# Out:
# 🚀 Mounting Google Drive for Server 2...
# Mounted at /content/drive
# ✅ Working directory set to: /content/drive/My Drive/Stock_Predictor_NSE/server2/backend

# %%
print("🚀 Installing prediction dependencies...")
# !pip install -r requirements.txt --quiet
print("✅ All libraries installed successfully.")
# Out:
# 🚀 Installing prediction dependencies...
# ✅ All libraries installed successfully.

# %%
print("\n🚀 Starting the Prediction server (server2) on T4 GPU...")
# yeh live logs dikhane ke liye foreground me chalega
# !python predict_app.py
# Out:
# 🚀 Starting the Prediction server (server2) on T4 GPU...
# 2025-09-29 14:48:10.599388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759157290.618941    1297 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759157290.624967    1297 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759157290.641438    1297 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
